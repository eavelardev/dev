# %% [markdown]
# # ReAct

# %% [markdown]
# ReAct (Reason+Act) combines reasoning and acting LLM capabilities in the same model.

# %%
question1 = "Seven Brief Lessons on Physics was written by an Italian physicist that has worked in France since what year?"
